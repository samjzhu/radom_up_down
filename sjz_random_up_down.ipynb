# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def randomUpDown(k):
    print(f'Samples={k}')
    arr = np.array(np.random.randint(2, size=k))
    # print(arr)
    c = np.count_nonzero(arr)
    print(f'Count of Ones: {c}')

    # Replace all 0 with -1
    v_arr = np.where(arr == 0, -1, arr)
    # print(v_arr)

    # Sum of values
    s_arr = []
    s = 0
    # continuous distribution
    dist = {}
    last_v = 0
    continuous_count = 0

    for v in v_arr:
        s += v
        s_arr.append(s)
        if v == last_v:
            continuous_count += 1
        else:
            current_sum = dist.get(continuous_count)
            if current_sum is None:
                current_sum = 0
            dist[continuous_count] = current_sum + 1
            continuous_count = 0
            last_v = v
    return s_arr, sorted(dist.items())

# %%
k = 100000

# %%
v, d = randomUpDown(k)
# Out:
# Samples=100000
# Count of Ones: 49832

# %%
print(f'Final value:{v[-1]}')
plt.plot(v)
plt.show()
# Out:
# Final value:-336

# %%
print(f'continuous distribution:{d}')
plt.plot(np.array(d)[:, 0], np.array(d)[:, 1])
plt.show()
# Out:
# continuous distribution:[(0, 24940), (1, 12490), (2, 6148), (3, 3118), (4, 1559), (5, 833), (6, 384), (7, 207), (8, 94), (9, 48), (10, 30), (11, 15), (12, 4), (13, 5), (14, 2), (16, 1), (19, 1)]
